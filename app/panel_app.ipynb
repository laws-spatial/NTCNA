# %%
import geopandas as gpd
import pandas as pd
import panel as pn 
import holoviews as hv

# %% [markdown]
# Census reorienting

# %%
# read in census.geojson into pandas dataframe from data folder that is in a different directory
census = gpd.read_file('../data/census2.geojson')
census.head()
# Out:
#         NAME PLACEFIPS       year  entityID  pl_age_total_und18  \
# 0     Santee   3143475 2011-06-01     43475                44.9
# 1    Rosalie   3142250 2011-06-01     42250                24.7
# 2       Macy   3130170 2011-06-01     30170                53.5
# 3   Walthill   3151245 2011-06-01     51245                33.7
# 4  Winnebago   3153275 2011-06-01     53275                48.0
#
#    pl_age_total_18_64  pl_age_total_ov65  pl_pop_total  pl_age_white_und18  \
# 0                54.5                0.6           334                 0.0
# 1                53.7               21.6           231                13.8
# 2                42.4                4.1           851                 0.0
# 3                54.9               11.4           861                10.1
# 4                47.0                5.0           996                 0.0
#
#    pl_age_white_18_64  ...  st_pov_asian_18  st_pov_pacisl_tot  \
# 0                94.4  ...              3.6               50.8
# 1                59.6  ...              3.6               50.8
# 2                15.4  ...              3.6               50.8
# 3                61.2  ...              3.6               50.8
# 4                75.0  ...              3.6               50.8
#
#    st_pov_pacisl_18  st_pov_other_tot  st_pov_other_18  st_pov_mult_tot  \
# 0              32.0              23.3             11.5             23.7
# 1              32.0              23.3             11.5             23.7
# 2              32.0              23.3             11.5             23.7
# 3              32.0              23.3             11.5             23.7
# 4              32.0              23.3             11.5             23.7
#
#    st_pov_mult_18  st_pov_his_tot  st_pov_his_18  \
# 0            14.3            24.3           12.7
# 1            14.3            24.3           12.7
# 2            14.3            24.3           12.7
# 3            14.3            24.3           12.7
# 4            14.3            24.3           12.7
#
#                                             geometry
# 0  POLYGON ((-97.85201 42.84192, -97.85185 42.841...
# 1  POLYGON ((-96.50927 42.06107, -96.50932 42.060...
# 2  POLYGON ((-96.37321 42.12605, -96.37278 42.125...
# 3  POLYGON ((-96.49161 42.15520, -96.49145 42.151...
# 4  POLYGON ((-96.46833 42.24599, -96.46834 42.245...
#
# [5 rows x 194 columns]

# %% [markdown]
# List of ethnicities

# %%
ethnic_list = ["white", "black", "nat", "asian", "pacisl", "other", "mult", "his", "total"]

# %% [markdown]
# Loop through list of ethnicities, subset dataframe, and add to list of dataframes

# %%
# create list of dataframes to concatenate
df_list = []

for ethnicity in ethnic_list:

    # replace column name
    col_repl = "_" + ethnicity

    # Get the columns that have "bl" in them
    sub_cols = [col for col in census.columns.tolist() if col_repl in col ]
    sub_cols = sub_cols + ["NAME", "year", "entityID", "geometry"]

    # subset the dataframe to only include the columns that have "bl" in them
    census_sub = census[sub_cols]
    census_sub.columns = census_sub.columns.str.replace(col_repl, "")

    # add ethnicity column and populate it with ethnicity
    census_sub = census_sub.assign(ethnicity = ethnicity)

    # append to list
    df_list.append(census_sub)

# %%
# concat geodataframes into census_oriented
census_oriented = pd.concat(df_list)
census_oriented.head()
# Out:
#    pl_age_und18  pl_age_18_64  pl_age_ov65  pl_pop  pl_medage  pl_pov_tot  \
# 0           0.0          94.4          5.6      18       62.8         0.0
# 1          13.8          59.6         26.6     188       45.3        17.6
# 2           0.0          15.4         84.6      26       84.1        28.6
# 3          10.1          61.2         28.7     129       61.1         6.2
# 4           0.0          75.0         25.0      20       33.5        33.3
#
#    pl_pov_18  us_age_und18  us_age_18_64  us_age_ov65  ...  st_age_ov65  \
# 0        0.0          22.2          64.9         14.8  ...         14.6
# 1        0.0          22.2          64.9         14.8  ...         14.6
# 2        0.0          22.2          64.9         14.8  ...         14.6
# 3        0.0          22.2          64.9         14.8  ...         14.6
# 4        0.0          22.2          64.9         14.8  ...         14.6
#
#     st_pop  st_medage  st_pov_tot  st_pov_18       NAME       year  entityID  \
# 0  1600661       38.2        10.1        3.0     Santee 2011-06-01     43475
# 1  1600661       38.2        10.1        3.0    Rosalie 2011-06-01     42250
# 2  1600661       38.2        10.1        3.0       Macy 2011-06-01     30170
# 3  1600661       38.2        10.1        3.0   Walthill 2011-06-01     51245
# 4  1600661       38.2        10.1        3.0  Winnebago 2011-06-01     53275
#
#                                             geometry  ethnicity
# 0  POLYGON ((-97.85201 42.84192, -97.85185 42.841...      white
# 1  POLYGON ((-96.50927 42.06107, -96.50932 42.060...      white
# 2  POLYGON ((-96.37321 42.12605, -96.37278 42.125...      white
# 3  POLYGON ((-96.49161 42.15520, -96.49145 42.151...      white
# 4  POLYGON ((-96.46833 42.24599, -96.46834 42.245...      white
#
# [5 rows x 26 columns]

# %% [markdown]
# Build charts for panel app

# %%
[print(col) for col in census_oriented.columns.tolist() if "_age" in col]
# Out:
# pl_age_und18
# pl_age_18_64
# pl_age_ov65
# us_age_und18
# us_age_18_64
# us_age_ov65
# st_age_und18
# st_age_18_64
# st_age_ov65
# [None, None, None, None, None, None, None, None, None]

# %%
# define function to create holoviz bar chart
def age_group_chart():

    # list of age groups
    age_cols = [col for col in census_oriented.columns.tolist() if "_age" in col]

    return hv.Bars(census, age_cols)

test = age_group_chart()
test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 9
#       5     age_cols = [col for col in census_oriented.columns.tolist() if "_age" in col]
#       7     return hv.Bars(census, age_cols)
# ----> 9 test = age_group_chart()
#      10 test
#
# Cell In[10], line 7, in age_group_chart()
#       2 def age_group_chart():
#       3
#       4     # list of age groups
#       5     age_cols = [col for col in census_oriented.columns.tolist() if "_age" in col]
# ----> 7     return hv.Bars(census, age_cols)
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\holoviews\element\selection.py:24, in SelectionIndexExpr.__init__(self, *args, **kwargs)
#      23 def __init__(self, *args, **kwargs):
# ---> 24     super().__init__(*args, **kwargs)
#      25     self._index_skip = False
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\holoviews\element\chart.py:51, in Chart.__init__(self, data, kdims, vdims, **params)
#      49 if len(params.get('kdims', [])) == self._max_kdim_count + 1:
#      50     self.param.warning('Chart elements should only be supplied a single kdim')
# ---> 51 super().__init__(data, **params)
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\holoviews\core\data\__init__.py:334, in Dataset.__init__(self, data, kdims, vdims, **kwargs)
#     331 initialized = Interface.initialize(type(self), data, kdims, vdims,
#     332                                    datatype=kwargs.get('datatype'))
#     333 (data, self.interface, dims, extra_kws) = initialized
# --> 334 super().__init__(data, **dict(kwargs, **dict(dims, **extra_kws)))
#     335 self.interface.validate(self, validate_vdims)
#     337 # Handle _pipeline property
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\holoviews\core\dimension.py:844, in Dimensioned.__init__(self, data, kdims, vdims, **params)
#     841 if 'cdims' in params:
#     842     params['cdims'] = {d if isinstance(d, Dimension) else Dimension(d): val
#     843                        for d, val in params['cdims'].items()}
# --> 844 super().__init__(data, **params)
#     845 self.ndims = len(self.kdims)
#     846 cdims = [(d.name, val) for d, val in self.cdims.items()]
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\holoviews\core\dimension.py:503, in LabelledData.__init__(self, data, id, plot_id, **params)
#     500     util.group_sanitizer.add_aliases(**{alias:long_name})
#     501     params['group'] = long_name
# --> 503 super().__init__(**params)
#     504 if not util.group_sanitizer.allowable(self.group):
#     505     raise ValueError("Supplied group %r contains invalid characters." %
#     506                      self.group)
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\param\parameterized.py:3173, in Parameterized.__init__(self, **params)
#    3170 self._dynamic_watchers = defaultdict(list)
#    3172 self.param._generate_name()
# -> 3173 self.param._setup_params(**params)
#    3174 object_count += 1
#    3176 self.param._update_deps(init=True)
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\param\parameterized.py:1387, in as_uninitialized.<locals>.override_initialization(self_, *args, **kw)
#    1385 original_initialized = parameterized_instance.initialized
#    1386 parameterized_instance.initialized = False
# -> 1387 fn(parameterized_instance, *args, **kw)
#    1388 parameterized_instance.initialized = original_initialized
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\param\parameterized.py:1641, in Parameters._setup_params(self_, **params)
#    1639     self.param.warning("Setting non-parameter attribute %s=%s using a mechanism intended only for parameters", name, val)
#    1640 # i.e. if not desc it's setting an attribute in __dict__, not a Parameter
# -> 1641 setattr(self, name, val)
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\param\parameterized.py:369, in instance_descriptor.<locals>._f(self, obj, val)
#     367     instance_param.__set__(obj, val)
#     368     return
# --> 369 return f(self, obj, val)
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\param\parameterized.py:1201, in Parameter.__set__(self, obj, val)
#    1198 if hasattr(self, 'set_hook'):
#    1199     val = self.set_hook(obj,val)
# -> 1201 self._validate(val)
#    1203 _old = NotImplemented
#    1204 # obj can be None if __set__ is called for a Parameterized class
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\param\__init__.py:1406, in List._validate(self, val)
#    1401 """
#    1402 Checks that the value is numeric and that it is within the hard
#    1403 bounds; if not, an exception is raised.
#    1404 """
#    1405 self._validate_value(val, self.allow_None)
# -> 1406 self._validate_bounds(val, self.bounds)
#    1407 self._validate_item_type(val, self.item_type)
#
# File c:\Users\Admin\miniconda3\envs\mn_squirrel_app\lib\site-packages\param\__init__.py:1417, in List._validate_bounds(self, val, bounds)
#    1415 if min_length is not None and max_length is not None:
#    1416     if not (min_length <= l <= max_length):
# -> 1417         raise ValueError("%s: list length must be between %s and %s (inclusive)"%(self.name,min_length,max_length))
#    1418 elif min_length is not None:
#    1419     if not min_length <= l:
#
# ValueError: kdims: list length must be between 1 and 3 (inclusive)
